# %%
kitap = "Masumiyet Müzesi"
kütüphane = "Hacettepe Üniversitesi Kütüphanesi"
kitapAdedi = 5
istenenKitapSayısı = 4
print(kitap)
print(kütüphane)
sonuc = istenenKitapSayısı > kitapAdedi
print(sonuc)
print("Alınmak istenen " + str(istenenKitapSayısı) + " " + kitap + " " + "kütüphanede mevcut değildir." )
print("alınabilir mi? " + str(sonuc))
# Out:
# Masumiyet Müzesi
# Hacettepe Üniversitesi Kütüphanesi
# False
# Alınmak istenen 4 Masumiyet Müzesi kütüphanede mevcut değildir.
# alınabilir mi? False
